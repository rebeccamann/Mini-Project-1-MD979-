# %%
import json


modelParameters = {
    '0-19' : {
        'd' : 0.0275,
        'h' : 0.002,
        'k' : 0.0276,
        'N' : round(70000000*0.223),
        'S_U0' : round((70000000*0.223)*0.999),
        'E_U0' : round((70000000*0.223)*0.0005),
        'I_SU0' : round((70000000*0.223)*0.00025),
        'I_AU0' : round((70000000*0.223)*0.00025),
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'beta' : 1.25,
        'epsilon' : 1/5.28,
        'gamma' : 1/7,
        'delta' : 1/10,
        'tau' : 0.25,
        'rho' : 0.1,
        'omega' : 1/100,
        'H_U0' : 0,
        'R_U0' : 0,
        'D_U0' : 0,
        'S_V0' : 0,
        'S_VI0' : 0,
        'E_V0' : 0,
        'I_SV0' : 0,
        'I_AV0' : 0,
        'H_V0' : 0,
        'R_V0' : 0,
        'D_V0' : 0,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta' : 0.7,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    },
    '20-64' : {
        'd' : 0.1350,
        'h' : 0.01,
        'k' : 0.0533,
        'N' : round(70000000*0.584),
        'S_U0' : round((70000000*0.584)*0.999),
        'E_U0' : round((70000000*0.584)*0.0005),
        'I_SU0' : round((70000000*0.584)*0.00025),
        'I_AU0' : round((70000000*0.584)*0.00025),
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'beta' : 1.25,
        'epsilon' : 1/5.28,
        'gamma' : 1/7,
        'delta' : 1/10,
        'tau' : 0.25,
        'rho' : 0.1,
        'omega' : 1/100,
        'H_U0' : 0,
        'R_U0' : 0,
        'D_U0' : 0,
        'S_V0' : 0,
        'S_VI0' : 0,
        'E_V0' : 0,
        'I_SV0' : 0,
        'I_AV0' : 0,
        'H_V0' : 0,
        'R_V0' : 0,
        'D_V0' : 0,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta' : 0.7,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    },
    '65+' : {
        'd' : 0.5374,
        'h' : 0.1144,
        'k' : 0.1935,
        'N' : round(70000000*0.193),
        'S_U0' : round((70000000*0.193)*0.999),
        'E_U0' : round((70000000*0.193)*0.0005),
        'I_SU0' : round((70000000*0.193)*0.00025),
        'I_AU0' : round((70000000*0.193)*0.00025),
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'beta' : 1.25,
        'epsilon' : 1/5.28,
        'gamma' : 1/7,
        'delta' : 1/10 ,
        'tau' : 0.25 ,
        'rho' : 0.1,
        'omega' : 1/100,
        'H_U0' : 0,
        'R_U0' : 0,
        'D_U0' : 0,
        'S_V0' : 0,
        'S_VI0' : 0,
        'E_V0' : 0,
        'I_SV0' : 0,
        'I_AV0' : 0,
        'H_V0' : 0,
        'R_V0' : 0,
        'D_V0' : 0,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta' : 0.7,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    }
}

output = json.dumps(modelParameters)

# %%
f = open("params.json", "w")
f.write(output)
f.close()
