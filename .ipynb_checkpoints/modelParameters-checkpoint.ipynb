# %%
import json


modelParameters = {
    '0-19' : {
        'd1' : 0.0275,
        'h1' : 0.002,
        'k1' : 0.0276,
        'd2' : 0.0275 * 0.5,
        'h2' : 0.002 * 0.5,
        'k2' : 0.0276 * 0.5,
        'N' : round(70000000*0.223),
        'beta1' : [1, 0.2, 0.03],
        'beta2' : [1*2, 0.2*2, 0.03*2],
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'compartments' : {
            'S_U0' : round((70000000*0.223*0.999)),
            'S1_V0' : 0,
            'S1_VI0' : 0,
            'S2_V0' : 0,
            'S2_VI0' : 0,
            
            'E1_U0' : round((70000000*0.223*0.0005)),
            'E1_V0' : 0,
            'E2_U0' : 0,
            'E2_V0' : 0,
            'E2_VI0' : 0,
                           
            'I1_SU0' : round((70000000*0.223*0.00025)),
            'I1_AU0' : round((70000000*0.223*0.00025)),
            'I1_RU0' : 0,
            'I1_SV0' : 0,
            'I1_AV0' : 0,
            'I1_RV0' : 0,
            'I2_SU0' : 0,
            'I2_AU0' : 0,
            'I2_RU0' : 0,
            'I2_SV0' : 0,
            'I2_AV0' : 0,
            'I2_RV0' : 0,
            'I2_SVI0' : 0,
            'I2_AVI0' : 0,
            'I2_RVI0' : 0,
                            
            'H1_U0' : 0,
            'H1_V0' : 0,
            'H2_U0' : 0,
            'H2_V0' : 0,
            'H2_VI0' : 0, 
                             
            'R1_U0' : 0,
            'R1_V0' : 0,
            'R2_U0' : 0,
            'R2_V0' : 0,
            'R2_VI0' : 0,  
                             
            'D1_U0' : 0,
            'D1_V0' : 0,
            'D2_U0' : 0,
            'D2_V0' : 0,
            'D2_VI0' : 0,
        },
        
        'epsilon1' : 1/5.28,
        'gamma1' : 1/7,
        'gamma1prime' : 1/4,
        'delta1' : 1/10,
        'delta1prime' : 1/5,
        'tau1' : 0.25,
        'rho1' : 0.1,
        'omega1' : 1/100,
        'epsilon2' : (1/5.28)*2,
        'gamma2' : 1/7,
        'gamma2prime' : 1/4,
        'delta2' : 1/10,
        'delta2prime' : 1/5,
        'tau2' : 0.5,
        'rho2' : 0.2,
        'omega2' : 1/80,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta1' : 0.7,
        'eta2' : 0.7*0.8,
        'outbreak2Start' : 366,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    },
    '20-64' : {
        'd1' : 0.1350,
        'h1' : 0.01,
        'k1' : 0.0533,
        'd2' : 0.1350 * 0.5,
        'h2' : 0.01 * 0.5,
        'k2' : 0.0533 * 0.5,
        'N' : round(70000000*0.584),
        'beta1' : [0.4, 0.3, 0.2],
        'beta2' : [0.4*2, 0.3*2, 0.2*2],
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'compartments' : {
            'S_U0' : round((70000000*0.584*0.999)),
            'S1_V0' : 0,
            'S1_VI0' : 0,
            'S2_V0' : 0,
            'S2_VI0' : 0,
            
            'E1_U0' : round((70000000*0.584*0.0005)),
            'E1_V0' : 0,
            'E2_U0' : 0,
            'E2_V0' : 0,
            'E2_VI0' :0,
                           
            'I1_SU0' : round((70000000*0.584*0.00025)),
            'I1_AU0' : round((70000000*0.584*0.00025)),
            'I1_RU0' : 0,
            'I1_SV0' : 0,
            'I1_AV0' : 0,
            'I1_RV0' : 0,
            'I2_SU0' : 0,
            'I2_AU0' : 0,
            'I2_RU0' : 0,
            'I2_SV0' : 0,
            'I2_AV0' : 0,
            'I2_RV0' : 0,
            'I2_SVI0' : 0,
            'I2_AVI0' : 0,
            'I2_RVI0' : 0,
                            
            'H1_U0' : 0,
            'H1_V0' : 0,
            'H2_U0' : 0,
            'H2_V0' : 0,
            'H2_VI0' : 0, 
                             
            'R1_U0' : 0,
            'R1_V0' : 0,
            'R2_U0' : 0,
            'R2_V0' : 0,
            'R2_VI0' : 0,  
                             
            'D1_U0' : 0,
            'D1_V0' : 0,
            'D2_U0' : 0,
            'D2_V0' : 0,
            'D2_VI0' : 0,
        },
        
        'epsilon1' : 1/5.28,
        'gamma1' : 1/7,
        'gamma1prime' : 1/4,
        'delta1' : 1/10,
        'delta1prime' : 1/5,
        'tau1' : 0.25,
        'rho1' : 0.1,
        'omega1' : 1/100,
        'epsilon2' : (1/5.28)*2,
        'gamma2' : 1/7,
        'gamma2prime' : 1/4,
        'delta2' : 1/10,
        'delta2prime' : 1/5,
        'tau2' : 0.5,
        'rho2' : 0.2,
        'omega2' : 1/80,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta1' : 0.7,
        'eta2' : 0.7*0.8,
        'outbreak2Start' : 366,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    },
    '65+' : {
        'd1' : 0.5374,
        'h1' : 0.1144,
        'k1' : 0.1935,
        'd2' : 0.5374 * 0.5 ,
        'h2' : 0.1144 * 0.5 ,
        'k2' : 0.1935 * 0.5 ,
        'N' : round(70000000*0.193),
        'beta1' : [0.1, 0.2, 0.2],
        'beta2' : [0.1*2, 0.2*2, 0.2*2],
        'vaccineStart' : 30,
        'compliance' : 4,
        
        'compartments' : {
            'S_U0' : round((70000000*0.193*0.999)),
            'S1_V0' : 0,
            'S1_VI0' : 0,
            'S2_V0' : 0,
            'S2_VI0' : 0,
            
            'E1_U0' : round((70000000*0.193*0.0005)),
            'E1_V0' : 0,
            'E2_U0' : 0,
            'E2_V0' : 0,
            'E2_VI0' :0,
                           
            'I1_SU0' : round((70000000*0.193*0.00025)),
            'I1_AU0' : round((70000000*0.193*0.00025)),
            'I1_RU0' : 0,
            'I1_SV0' : 0,
            'I1_AV0' : 0,
            'I1_RV0' : 0,
            'I2_SU0' : 0,
            'I2_AU0' : 0,
            'I2_RU0' : 0,
            'I2_SV0' : 0,
            'I2_AV0' : 0,
            'I2_RV0' : 0,
            'I2_SVI0' : 0,
            'I2_AVI0' : 0,
            'I2_RVI0' : 0,
                            
            'H1_U0' : 0,
            'H1_V0' : 0,
            'H2_U0' : 0,
            'H2_V0' : 0,
            'H2_VI0' : 0, 
                             
            'R1_U0' : 0,
            'R1_V0' : 0,
            'R2_U0' : 0,
            'R2_V0' : 0,
            'R2_VI0' : 0,  
                             
            'D1_U0' : 0,
            'D1_V0' : 0,
            'D2_U0' : 0,
            'D2_V0' : 0,
            'D2_VI0' : 0,
        },
        
        'epsilon1' : 1/5.28,
        'gamma1' : 1/7,
        'gamma1prime' : 1/4,
        'delta1' : 1/10 ,
        'delta1prime' : 1/5,
        'tau1' : 0.25 ,
        'rho1' : 0.1,
        'omega1' : 1/100,
        'epsilon2' : (1/5.28)*2,
        'gamma2' : 1/7,
        'gamma2prime' : 1/4,
        'delta2' : 1/10,
        'delta2prime' : 1/5,
        'tau2' : 0.5,
        'rho2' : 0.2,
        'omega2' : 1/80,
        't_start' : 0,
        'days' : 365,
        't_step': 1.0,
        'sigma' : 0.04,
        'eta1' : 0.7,
        'eta2' : 0.7*0.8,
        'outbreak2Start' : 366,
        'lockdown1Start' : 30,
        'lockdown1End' : 50,
        'lockdown2Start' : 60,
        'lockdown2End' : 90,
        'easing' : 0.2,
    }
}

output = json.dumps(modelParameters)

# %%
f = open("params.json", "w")
f.write(output)
f.close()
